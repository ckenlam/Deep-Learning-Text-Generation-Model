# %% [markdown]
# # Text Generation with LSTM

# %% [markdown]
# <img src="https://github.com/ckenlam/Deep-Learning-Text-Generation-Model/blob/master/bro-code-lstm.png?raw=true" width="700">

# %% [markdown]
# Inspired by Janelle Shane's [Pickup Line Generator](https://aiweirdness.com/post/159302925452/the-neural-network-generated-pickup-lines-that-are), I will attempt to train a recurrent neural network that can come up with its own Bro Codes using data from the following sources:
# - https://brocode.org/the-code/
# - http://www.fanpop.com/clubs/barney-stinson/articles/162623/title/chicks-code

# %% [markdown]
# ## Loading the Libraies

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from keras.models import Sequential
import keras.utils as ku
from tqdm import tqdm
import re
import requests
# Out:
# C:\Users\ken.lam\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the data

# %% [markdown]
# I gathered all 184 Bro Codes and 125 Chick Codes and saved them in a text file. As you can imagine, this is a very small dataset of 309 documents; we shall see what kind of outputs we can get from this dataset.

# %%
url = 'https://raw.githubusercontent.com/ckenlam/Deep-Learning-Text-Generation-Model/master/data.txt'
response = requests.get(url)
data = response.text

# %% [markdown]
# ## Data Processing

# %% [markdown]
# To generate realistic sentences, I need to preserve the punctuations in the dataset. However, Keras' Tokenizer will remove all punctuations by default. To get around that, I will have to add a space to any punctuations and remove the desired punctuations from Tokenizer's filter.

# %%
data = re.sub('\d+: ','', data)
cleanup_dict = {"ARTICLE ":""
               ,".":" ."
               ,",":" ,"
               ,"!":" !"
               ,"?":" ?"
               ,"\r\n":"\n"
               ,"\n\n":"\n"
                }
for from_this, to_this in cleanup_dict.items():
    data = data.replace(from_this, to_this)

# %% [markdown]
# A text generation model requires each document to be split into N-gram sequences and 1 associated next-word. Simply put, the sentence "Bro’s do not keep a personal diary" need to be transformed into the following:
# 1. Bro's + **do**
# 2. Bro's do + **not**
# 3. Bro's do not + **keep**
# 4. Bro's do not keep + **a**
# 5. Bro's do not keep a + **personal**
# 6. Bro's do not keep a personal + **diary**
#
# The underlying idea of text generation model is essentially a language model that predicts the probability of each word given an input sequence of text. The predicted word will then be added to the previous input sequence which will be used to generate the next word again. The cycle repeats for an arbitrary number of times.
#
# The following data processing function is based on the one found in Shivam Bansal's [article](https://medium.com/@shivambansal36/language-modelling-text-generation-using-lstms-deep-learning-for-nlp-ed36b224b275).

# %%
tokenizer = Tokenizer(filters='"#$%&()*+-/:;<=>@[\\]^_`{|}~\t\n')

def data_processing(text_data):
    text = text_data.lower().split('\n')
    tokenizer.fit_on_texts(text)
    words_count = len(tokenizer.word_index)+1
    sequences = []
    
    #For each line in the text data, tokenize each word
    for line in text:
        tokenized_line = tokenizer.texts_to_sequences([line])[0]
        
    #Turn each tokenized line into n-gram sequences and append to the "sequences" list
        for seq in range(1, len(tokenized_line)):
            n_gram_seq = tokenized_line[:seq+1]
            sequences.append(n_gram_seq)
            
    #Find the maximum length in this dataset
    max_sequence_length = max(len(x) for x in sequences)
    
    #Make sure all n-gram sequences are of the same length
    sequences = pad_sequences(sequences,maxlen=max_sequence_length,padding='pre')
    X = sequences[:,:-1]
    y = sequences[:,-1]
    y = ku.to_categorical(y, num_classes=words_count)
    word_index = tokenizer.word_index
    return X,y,max_sequence_length,words_count, word_index

# %%
X, y, max_seq_length, total_words_count, word_index = data_processing(data)

# %% [markdown]
# ## Defining the Models

# %% [markdown]
# For this experiment, I will train a neural network with 3 hidden layers of bidirectional LSTM without using a pre-trained word embedding to initialize the embedding layer.

# %%
model = Sequential()
model.add(Embedding(total_words_count, 10, input_length=max_seq_length - 1))
model.add(Bidirectional(LSTM(150, dropout=0.6, recurrent_dropout=0.6,return_sequences=True)))
model.add(Bidirectional(LSTM(150, dropout=0.6, recurrent_dropout=0.6,return_sequences=True)))
model.add(Bidirectional(LSTM(150)))
model.add(Dropout(0.1))
model.add(Dense(total_words_count,activation='softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 136, 10)           16700
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 136, 300)          193200
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 136, 300)          541200
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 300)               541200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1670)              502670
# =================================================================
# Total params: 1,794,970
# Trainable params: 1,794,970
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the Models

# %%
from keras.callbacks import History 
from keras.callbacks import EarlyStopping
batch_size = 50
epochs = 200

# %%
from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(X, y, epochs=epochs, verbose = 1
                      , batch_size=batch_size
                      , callbacks=callbacks_list
                      ,validation_split=0.2
                      #,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)]
                     )
print("Training completed!")
model.save('model.h5')
# Out:
# W0619 02:27:07.843797 140585019008896 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 5757 samples, validate on 1440 samples
# Epoch 1/200
# 5757/5757 [==============================] - 192s 33ms/step - loss: 6.2922 - acc: 0.0493 - val_loss: 6.1714 - val_acc: 0.0625
#
# Epoch 00001: val_acc improved from -inf to 0.06250, saving model to weights-improvement-01-0.06.hdf5
# Epoch 2/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 5.8778 - acc: 0.0535 - val_loss: 6.3218 - val_acc: 0.0625
#
# Epoch 00002: val_acc did not improve from 0.06250
# Epoch 3/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 5.8433 - acc: 0.0516 - val_loss: 6.3605 - val_acc: 0.0625
#
# Epoch 00003: val_acc improved from 0.06250 to 0.06250, saving model to weights-improvement-03-0.06.hdf5
# Epoch 4/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 5.8284 - acc: 0.0514 - val_loss: 6.4333 - val_acc: 0.0625
#
# Epoch 00004: val_acc did not improve from 0.06250
# Epoch 5/200
# 5757/5757 [==============================] - 183s 32ms/step - loss: 5.7875 - acc: 0.0523 - val_loss: 6.3706 - val_acc: 0.0625
#
# Epoch 00005: val_acc did not improve from 0.06250
# Epoch 6/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 5.6720 - acc: 0.0519 - val_loss: 6.4128 - val_acc: 0.0576
#
# Epoch 00006: val_acc did not improve from 0.06250
# Epoch 7/200
# 5757/5757 [==============================] - 181s 31ms/step - loss: 5.6035 - acc: 0.0599 - val_loss: 6.5470 - val_acc: 0.0493
#
# Epoch 00007: val_acc did not improve from 0.06250
# Epoch 8/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 5.5364 - acc: 0.0681 - val_loss: 6.4536 - val_acc: 0.0521
#
# Epoch 00008: val_acc did not improve from 0.06250
# Epoch 9/200
# 5757/5757 [==============================] - 181s 31ms/step - loss: 5.4623 - acc: 0.0702 - val_loss: 6.4892 - val_acc: 0.0507
#
# Epoch 00009: val_acc did not improve from 0.06250
# Epoch 10/200
# 5757/5757 [==============================] - 179s 31ms/step - loss: 5.3871 - acc: 0.0763 - val_loss: 6.5055 - val_acc: 0.0382
#
# Epoch 00010: val_acc did not improve from 0.06250
# Epoch 11/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 5.3040 - acc: 0.0891 - val_loss: 6.4813 - val_acc: 0.0646
#
# Epoch 00011: val_acc improved from 0.06250 to 0.06458, saving model to weights-improvement-11-0.06.hdf5
# Epoch 12/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 5.2220 - acc: 0.1018 - val_loss: 6.5505 - val_acc: 0.0625
#
# Epoch 00012: val_acc did not improve from 0.06458
# Epoch 13/200
# 5757/5757 [==============================] - 183s 32ms/step - loss: 5.1400 - acc: 0.0994 - val_loss: 6.5025 - val_acc: 0.0653
#
# Epoch 00013: val_acc improved from 0.06458 to 0.06528, saving model to weights-improvement-13-0.07.hdf5
# Epoch 14/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 5.0679 - acc: 0.1089 - val_loss: 6.5732 - val_acc: 0.0632
#
# Epoch 00014: val_acc did not improve from 0.06528
# Epoch 15/200
# 5757/5757 [==============================] - 183s 32ms/step - loss: 5.0046 - acc: 0.1110 - val_loss: 6.5628 - val_acc: 0.0611
#
# Epoch 00015: val_acc did not improve from 0.06528
# Epoch 16/200
# 5757/5757 [==============================] - 181s 32ms/step - loss: 4.9334 - acc: 0.1195 - val_loss: 6.5521 - val_acc: 0.0653
#
# Epoch 00016: val_acc did not improve from 0.06528
# Epoch 17/200
# 5757/5757 [==============================] - 181s 31ms/step - loss: 4.8667 - acc: 0.1183 - val_loss: 6.5433 - val_acc: 0.0806
#
# Epoch 00017: val_acc improved from 0.06528 to 0.08056, saving model to weights-improvement-17-0.08.hdf5
# Epoch 18/200
# 5757/5757 [==============================] - 181s 31ms/step - loss: 4.7824 - acc: 0.1355 - val_loss: 6.6516 - val_acc: 0.0750
#
# Epoch 00018: val_acc did not improve from 0.08056
# Epoch 19/200
# 5757/5757 [==============================] - 179s 31ms/step - loss: 4.7149 - acc: 0.1353 - val_loss: 6.6036 - val_acc: 0.0778
#
# Epoch 00019: val_acc did not improve from 0.08056
# Epoch 20/200
# 5757/5757 [==============================] - 179s 31ms/step - loss: 4.6589 - acc: 0.1424 - val_loss: 6.6744 - val_acc: 0.0840
#
# Epoch 00020: val_acc improved from 0.08056 to 0.08403, saving model to weights-improvement-20-0.08.hdf5
# Epoch 21/200
# 5757/5757 [==============================] - 179s 31ms/step - loss: 4.5903 - acc: 0.1431 - val_loss: 6.6741 - val_acc: 0.0847
#
# Epoch 00021: val_acc improved from 0.08403 to 0.08472, saving model to weights-improvement-21-0.08.hdf5
# Epoch 22/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 4.5161 - acc: 0.1504 - val_loss: 6.7131 - val_acc: 0.0854
#
# Epoch 00022: val_acc improved from 0.08472 to 0.08542, saving model to weights-improvement-22-0.09.hdf5
# Epoch 23/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 4.4614 - acc: 0.1490 - val_loss: 6.7460 - val_acc: 0.0896
#
# Epoch 00023: val_acc improved from 0.08542 to 0.08958, saving model to weights-improvement-23-0.09.hdf5
# Epoch 24/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 4.4030 - acc: 0.1548 - val_loss: 6.7935 - val_acc: 0.0910
#
# Epoch 00024: val_acc improved from 0.08958 to 0.09097, saving model to weights-improvement-24-0.09.hdf5
# Epoch 25/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 4.3304 - acc: 0.1569 - val_loss: 6.7757 - val_acc: 0.0924
#
# Epoch 00025: val_acc improved from 0.09097 to 0.09236, saving model to weights-improvement-25-0.09.hdf5
# Epoch 26/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 4.2726 - acc: 0.1591 - val_loss: 6.8230 - val_acc: 0.0896
#
# Epoch 00026: val_acc did not improve from 0.09236
# Epoch 27/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 4.2141 - acc: 0.1636 - val_loss: 6.8588 - val_acc: 0.0833
#
# Epoch 00027: val_acc did not improve from 0.09236
# Epoch 28/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 4.1569 - acc: 0.1640 - val_loss: 6.8819 - val_acc: 0.0903
#
# Epoch 00028: val_acc did not improve from 0.09236
# Epoch 29/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 4.0964 - acc: 0.1680 - val_loss: 6.9379 - val_acc: 0.0812
#
# Epoch 00029: val_acc did not improve from 0.09236
# Epoch 30/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 4.0460 - acc: 0.1721 - val_loss: 6.9719 - val_acc: 0.0903
#
# Epoch 00030: val_acc did not improve from 0.09236
# Epoch 31/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.9937 - acc: 0.1704 - val_loss: 7.0074 - val_acc: 0.0826
#
# Epoch 00031: val_acc did not improve from 0.09236
# Epoch 32/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.9339 - acc: 0.1739 - val_loss: 6.9874 - val_acc: 0.0889
#
# Epoch 00032: val_acc did not improve from 0.09236
# Epoch 33/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.8855 - acc: 0.1826 - val_loss: 7.0455 - val_acc: 0.0819
#
# Epoch 00033: val_acc did not improve from 0.09236
# Epoch 34/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.8337 - acc: 0.1833 - val_loss: 7.0962 - val_acc: 0.0875
#
# Epoch 00034: val_acc did not improve from 0.09236
# Epoch 35/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 3.7758 - acc: 0.1826 - val_loss: 7.1420 - val_acc: 0.0861
#
# Epoch 00035: val_acc did not improve from 0.09236
# Epoch 36/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 3.7222 - acc: 0.1881 - val_loss: 7.1388 - val_acc: 0.0882
#
# Epoch 00036: val_acc did not improve from 0.09236
# Epoch 37/200
# 5757/5757 [==============================] - 182s 32ms/step - loss: 3.7029 - acc: 0.1869 - val_loss: 7.1225 - val_acc: 0.0937
#
# Epoch 00037: val_acc improved from 0.09236 to 0.09375, saving model to weights-improvement-37-0.09.hdf5
# Epoch 38/200
# 5757/5757 [==============================] - 181s 31ms/step - loss: 3.6557 - acc: 0.1871 - val_loss: 7.2054 - val_acc: 0.0924
#
# Epoch 00038: val_acc did not improve from 0.09375
# Epoch 39/200
# 5757/5757 [==============================] - 180s 31ms/step - loss: 3.6000 - acc: 0.1951 - val_loss: 7.2127 - val_acc: 0.0903
#
# Epoch 00039: val_acc did not improve from 0.09375
# Epoch 40/200
# 5757/5757 [==============================] - 179s 31ms/step - loss: 3.5597 - acc: 0.1984 - val_loss: 7.2010 - val_acc: 0.0931
#
# Epoch 00040: val_acc did not improve from 0.09375
# Epoch 41/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 3.5097 - acc: 0.2097 - val_loss: 7.2738 - val_acc: 0.0882
#
# Epoch 00041: val_acc did not improve from 0.09375
# Epoch 42/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 3.4704 - acc: 0.2074 - val_loss: 7.2607 - val_acc: 0.0931
#
# Epoch 00042: val_acc did not improve from 0.09375
# Epoch 43/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 3.4222 - acc: 0.2187 - val_loss: 7.3436 - val_acc: 0.0924
#
# Epoch 00043: val_acc did not improve from 0.09375
# Epoch 44/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 3.3798 - acc: 0.2196 - val_loss: 7.3303 - val_acc: 0.0840
#
# Epoch 00044: val_acc did not improve from 0.09375
# Epoch 45/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.3363 - acc: 0.2274 - val_loss: 7.3763 - val_acc: 0.0868
#
# Epoch 00045: val_acc did not improve from 0.09375
# Epoch 46/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.3045 - acc: 0.2343 - val_loss: 7.3630 - val_acc: 0.0979
#
# Epoch 00046: val_acc improved from 0.09375 to 0.09792, saving model to weights-improvement-46-0.10.hdf5
# Epoch 47/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.2471 - acc: 0.2394 - val_loss: 7.3589 - val_acc: 0.0861
#
# Epoch 00047: val_acc did not improve from 0.09792
# Epoch 48/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.2098 - acc: 0.2579 - val_loss: 7.4291 - val_acc: 0.0854
#
# Epoch 00048: val_acc did not improve from 0.09792
# Epoch 49/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.1658 - acc: 0.2526 - val_loss: 7.4300 - val_acc: 0.0868
#
# Epoch 00049: val_acc did not improve from 0.09792
# Epoch 50/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.1238 - acc: 0.2718 - val_loss: 7.4534 - val_acc: 0.0903
#
# Epoch 00050: val_acc did not improve from 0.09792
# Epoch 51/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 3.0824 - acc: 0.2753 - val_loss: 7.4759 - val_acc: 0.0903
#
# Epoch 00051: val_acc did not improve from 0.09792
# Epoch 52/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 3.0380 - acc: 0.2883 - val_loss: 7.5088 - val_acc: 0.0924
#
# Epoch 00052: val_acc did not improve from 0.09792
# Epoch 53/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 3.0101 - acc: 0.2920 - val_loss: 7.5411 - val_acc: 0.0875
#
# Epoch 00053: val_acc did not improve from 0.09792
# Epoch 54/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.9624 - acc: 0.3036 - val_loss: 7.5253 - val_acc: 0.0875
#
# Epoch 00054: val_acc did not improve from 0.09792
# Epoch 55/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.9261 - acc: 0.3125 - val_loss: 7.5591 - val_acc: 0.0889
#
# Epoch 00055: val_acc did not improve from 0.09792
# Epoch 56/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.8851 - acc: 0.3174 - val_loss: 7.6110 - val_acc: 0.0931
#
# Epoch 00056: val_acc did not improve from 0.09792
# Epoch 57/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.8424 - acc: 0.3292 - val_loss: 7.6359 - val_acc: 0.0937
#
# Epoch 00057: val_acc did not improve from 0.09792
# Epoch 58/200
# 5757/5757 [==============================] - 176s 30ms/step - loss: 2.8246 - acc: 0.3269 - val_loss: 7.6501 - val_acc: 0.0882
#
# Epoch 00058: val_acc did not improve from 0.09792
# Epoch 59/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.7902 - acc: 0.3312 - val_loss: 7.6580 - val_acc: 0.0944
#
# Epoch 00059: val_acc did not improve from 0.09792
# Epoch 60/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.7470 - acc: 0.3439 - val_loss: 7.6738 - val_acc: 0.0951
#
# Epoch 00060: val_acc did not improve from 0.09792
# Epoch 61/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.7024 - acc: 0.3603 - val_loss: 7.6815 - val_acc: 0.0937
#
# Epoch 00061: val_acc did not improve from 0.09792
# Epoch 62/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.6871 - acc: 0.3552 - val_loss: 7.7108 - val_acc: 0.0924
#
# Epoch 00062: val_acc did not improve from 0.09792
# Epoch 63/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.6501 - acc: 0.3646 - val_loss: 7.7250 - val_acc: 0.0965
#
# Epoch 00063: val_acc did not improve from 0.09792
# Epoch 64/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.6228 - acc: 0.3649 - val_loss: 7.7285 - val_acc: 0.0917
#
# Epoch 00064: val_acc did not improve from 0.09792
# Epoch 65/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.5772 - acc: 0.3754 - val_loss: 7.7591 - val_acc: 0.0972
#
# Epoch 00065: val_acc did not improve from 0.09792
# Epoch 66/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.5540 - acc: 0.3839 - val_loss: 7.7677 - val_acc: 0.0938
#
# Epoch 00066: val_acc did not improve from 0.09792
# Epoch 67/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.5203 - acc: 0.3834 - val_loss: 7.7900 - val_acc: 0.0917
#
# Epoch 00067: val_acc did not improve from 0.09792
# Epoch 68/200
# 5757/5757 [==============================] - 176s 30ms/step - loss: 2.5017 - acc: 0.3943 - val_loss: 7.7799 - val_acc: 0.0903
#
# Epoch 00068: val_acc did not improve from 0.09792
# Epoch 69/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.4628 - acc: 0.4025 - val_loss: 7.8017 - val_acc: 0.0986
#
# Epoch 00069: val_acc improved from 0.09792 to 0.09861, saving model to weights-improvement-69-0.10.hdf5
# Epoch 70/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.4470 - acc: 0.4072 - val_loss: 7.8478 - val_acc: 0.0924
#
# Epoch 00070: val_acc did not improve from 0.09861
# Epoch 71/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.4078 - acc: 0.4108 - val_loss: 7.8541 - val_acc: 0.0917
#
# Epoch 00071: val_acc did not improve from 0.09861
# Epoch 72/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.3783 - acc: 0.4153 - val_loss: 7.8712 - val_acc: 0.0868
#
# Epoch 00072: val_acc did not improve from 0.09861
# Epoch 73/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.3642 - acc: 0.4169 - val_loss: 7.8817 - val_acc: 0.0889
#
# Epoch 00073: val_acc did not improve from 0.09861
# Epoch 74/200
# 5757/5757 [==============================] - 176s 30ms/step - loss: 2.3476 - acc: 0.4257 - val_loss: 7.8992 - val_acc: 0.0937
#
# Epoch 00074: val_acc did not improve from 0.09861
# Epoch 75/200
# 5757/5757 [==============================] - 176s 30ms/step - loss: 2.3155 - acc: 0.4261 - val_loss: 7.8976 - val_acc: 0.0910
#
# Epoch 00075: val_acc did not improve from 0.09861
# Epoch 76/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.2791 - acc: 0.4396 - val_loss: 7.9379 - val_acc: 0.0931
#
# Epoch 00076: val_acc did not improve from 0.09861
# Epoch 77/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.2629 - acc: 0.4436 - val_loss: 7.9407 - val_acc: 0.0944
#
# Epoch 00077: val_acc did not improve from 0.09861
# Epoch 78/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.2351 - acc: 0.4424 - val_loss: 7.9704 - val_acc: 0.0910
#
# Epoch 00078: val_acc did not improve from 0.09861
# Epoch 79/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.2285 - acc: 0.4468 - val_loss: 7.9874 - val_acc: 0.0903
#
# Epoch 00079: val_acc did not improve from 0.09861
# Epoch 80/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 2.1967 - acc: 0.4534 - val_loss: 7.9887 - val_acc: 0.0910
#
# Epoch 00080: val_acc did not improve from 0.09861
# Epoch 81/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 2.1719 - acc: 0.4669 - val_loss: 8.0078 - val_acc: 0.0938
#
# Epoch 00081: val_acc did not improve from 0.09861
# Epoch 82/200
# 5757/5757 [==============================] - 178s 31ms/step - loss: 2.1354 - acc: 0.4714 - val_loss: 8.0001 - val_acc: 0.0965
#
# Epoch 00082: val_acc did not improve from 0.09861
# Epoch 83/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 2.1248 - acc: 0.4686 - val_loss: 8.0139 - val_acc: 0.0937
#
# Epoch 00083: val_acc did not improve from 0.09861
# Epoch 84/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.1049 - acc: 0.4683 - val_loss: 8.0462 - val_acc: 0.0896
#
# Epoch 00084: val_acc did not improve from 0.09861
# Epoch 85/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 2.0741 - acc: 0.4759 - val_loss: 8.0483 - val_acc: 0.0917
#
# Epoch 00085: val_acc did not improve from 0.09861
# Epoch 86/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.0554 - acc: 0.4792 - val_loss: 8.0744 - val_acc: 0.0833
#
# Epoch 00086: val_acc did not improve from 0.09861
# Epoch 87/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.0280 - acc: 0.4884 - val_loss: 8.0681 - val_acc: 0.0924
#
# Epoch 00087: val_acc did not improve from 0.09861
# Epoch 88/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 2.0047 - acc: 0.4950 - val_loss: 8.0934 - val_acc: 0.0889
#
# Epoch 00088: val_acc did not improve from 0.09861
# Epoch 89/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.9801 - acc: 0.4904 - val_loss: 8.1126 - val_acc: 0.0889
#
# Epoch 00089: val_acc did not improve from 0.09861
# Epoch 90/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.9620 - acc: 0.5063 - val_loss: 8.1264 - val_acc: 0.0924
#
# Epoch 00090: val_acc did not improve from 0.09861
# Epoch 91/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.9527 - acc: 0.4983 - val_loss: 8.1220 - val_acc: 0.0986
#
# Epoch 00091: val_acc improved from 0.09861 to 0.09861, saving model to weights-improvement-91-0.10.hdf5
# Epoch 92/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.9376 - acc: 0.5117 - val_loss: 8.1239 - val_acc: 0.0993
#
# Epoch 00092: val_acc improved from 0.09861 to 0.09931, saving model to weights-improvement-92-0.10.hdf5
# Epoch 93/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.8969 - acc: 0.5192 - val_loss: 8.1471 - val_acc: 0.0931
#
# Epoch 00093: val_acc did not improve from 0.09931
# Epoch 94/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.8604 - acc: 0.5253 - val_loss: 8.1767 - val_acc: 0.0931
#
# Epoch 00094: val_acc did not improve from 0.09931
# Epoch 95/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.8561 - acc: 0.5281 - val_loss: 8.1759 - val_acc: 0.0972
#
# Epoch 00095: val_acc did not improve from 0.09931
# Epoch 96/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.8412 - acc: 0.5274 - val_loss: 8.1877 - val_acc: 0.0938
#
# Epoch 00096: val_acc did not improve from 0.09931
# Epoch 97/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.8300 - acc: 0.5287 - val_loss: 8.1922 - val_acc: 0.0965
#
# Epoch 00097: val_acc did not improve from 0.09931
# Epoch 98/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.7973 - acc: 0.5373 - val_loss: 8.2108 - val_acc: 0.0972
#
# Epoch 00098: val_acc did not improve from 0.09931
# Epoch 99/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.7835 - acc: 0.5393 - val_loss: 8.2325 - val_acc: 0.1014
#
# Epoch 00099: val_acc improved from 0.09931 to 0.10139, saving model to weights-improvement-99-0.10.hdf5
# Epoch 100/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.7617 - acc: 0.5402 - val_loss: 8.2259 - val_acc: 0.0937
#
# Epoch 00100: val_acc did not improve from 0.10139
# Epoch 101/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 1.8704 - acc: 0.5173 - val_loss: 8.1615 - val_acc: 0.0965
#
# Epoch 00101: val_acc did not improve from 0.10139
# Epoch 102/200
# 5757/5757 [==============================] - 177s 31ms/step - loss: 1.9174 - acc: 0.5107 - val_loss: 8.2031 - val_acc: 0.0937
#
# Epoch 00102: val_acc did not improve from 0.10139
# Epoch 103/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.7993 - acc: 0.5301 - val_loss: 8.2333 - val_acc: 0.0958
#
# Epoch 00103: val_acc did not improve from 0.10139
# Epoch 104/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.7491 - acc: 0.5489 - val_loss: 8.2593 - val_acc: 0.1035
#
# Epoch 00104: val_acc improved from 0.10139 to 0.10347, saving model to weights-improvement-104-0.10.hdf5
# Epoch 105/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.7784 - acc: 0.5348 - val_loss: 8.2626 - val_acc: 0.0993
#
# Epoch 00105: val_acc did not improve from 0.10347
# Epoch 106/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.6884 - acc: 0.5642 - val_loss: 8.2823 - val_acc: 0.0972
#
# Epoch 00106: val_acc did not improve from 0.10347
# Epoch 107/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.6690 - acc: 0.5675 - val_loss: 8.3310 - val_acc: 0.0993
#
# Epoch 00107: val_acc did not improve from 0.10347
# Epoch 108/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.6716 - acc: 0.5666 - val_loss: 8.3089 - val_acc: 0.1021
#
# Epoch 00108: val_acc did not improve from 0.10347
# Epoch 109/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.6475 - acc: 0.5765 - val_loss: 8.3200 - val_acc: 0.0979
#
# Epoch 00109: val_acc did not improve from 0.10347
# Epoch 110/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.6397 - acc: 0.5704 - val_loss: 8.3004 - val_acc: 0.1125
#
# Epoch 00110: val_acc improved from 0.10347 to 0.11250, saving model to weights-improvement-110-0.11.hdf5
# Epoch 111/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.6010 - acc: 0.5807 - val_loss: 8.3367 - val_acc: 0.1000
#
# Epoch 00111: val_acc did not improve from 0.11250
# Epoch 112/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5707 - acc: 0.5911 - val_loss: 8.3473 - val_acc: 0.0993
#
# Epoch 00112: val_acc did not improve from 0.11250
# Epoch 113/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.6367 - acc: 0.5767 - val_loss: 8.3612 - val_acc: 0.0965
#
# Epoch 00113: val_acc did not improve from 0.11250
# Epoch 114/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.6398 - acc: 0.5664 - val_loss: 8.3249 - val_acc: 0.0958
#
# Epoch 00114: val_acc did not improve from 0.11250
# Epoch 115/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5762 - acc: 0.5904 - val_loss: 8.3742 - val_acc: 0.1021
#
# Epoch 00115: val_acc did not improve from 0.11250
# Epoch 116/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5445 - acc: 0.5968 - val_loss: 8.3734 - val_acc: 0.0986
#
# Epoch 00116: val_acc did not improve from 0.11250
# Epoch 117/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5355 - acc: 0.5935 - val_loss: 8.3968 - val_acc: 0.1014
#
# Epoch 00117: val_acc did not improve from 0.11250
# Epoch 118/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5103 - acc: 0.5927 - val_loss: 8.3969 - val_acc: 0.1146
#
# Epoch 00118: val_acc improved from 0.11250 to 0.11458, saving model to weights-improvement-118-0.11.hdf5
# Epoch 119/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5049 - acc: 0.6019 - val_loss: 8.4255 - val_acc: 0.1035
#
# Epoch 00119: val_acc did not improve from 0.11458
# Epoch 120/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.5496 - acc: 0.5897 - val_loss: 8.4023 - val_acc: 0.1042
#
# Epoch 00120: val_acc did not improve from 0.11458
# Epoch 121/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5102 - acc: 0.6057 - val_loss: 8.4171 - val_acc: 0.0986
#
# Epoch 00121: val_acc did not improve from 0.11458
# Epoch 122/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.5116 - acc: 0.6043 - val_loss: 8.4072 - val_acc: 0.1125
#
# Epoch 00122: val_acc did not improve from 0.11458
# Epoch 123/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.4701 - acc: 0.6173 - val_loss: 8.4308 - val_acc: 0.1021
#
# Epoch 00123: val_acc did not improve from 0.11458
# Epoch 124/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.4505 - acc: 0.6100 - val_loss: 8.4591 - val_acc: 0.1049
#
# Epoch 00124: val_acc did not improve from 0.11458
# Epoch 125/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.4512 - acc: 0.6165 - val_loss: 8.4981 - val_acc: 0.1014
#
# Epoch 00125: val_acc did not improve from 0.11458
# Epoch 126/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.4233 - acc: 0.6243 - val_loss: 8.4864 - val_acc: 0.1007
#
# Epoch 00126: val_acc did not improve from 0.11458
# Epoch 127/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.4082 - acc: 0.6269 - val_loss: 8.5009 - val_acc: 0.1000
#
# Epoch 00127: val_acc did not improve from 0.11458
# Epoch 128/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.4138 - acc: 0.6305 - val_loss: 8.4972 - val_acc: 0.1062
#
# Epoch 00128: val_acc did not improve from 0.11458
# Epoch 129/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.4101 - acc: 0.6212 - val_loss: 8.4981 - val_acc: 0.1000
#
# Epoch 00129: val_acc did not improve from 0.11458
# Epoch 130/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.4016 - acc: 0.6220 - val_loss: 8.5140 - val_acc: 0.0931
#
# Epoch 00130: val_acc did not improve from 0.11458
# Epoch 131/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.3923 - acc: 0.6283 - val_loss: 8.5232 - val_acc: 0.0965
#
# Epoch 00131: val_acc did not improve from 0.11458
# Epoch 132/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.3622 - acc: 0.6357 - val_loss: 8.5273 - val_acc: 0.1021
#
# Epoch 00132: val_acc did not improve from 0.11458
# Epoch 133/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.3393 - acc: 0.6453 - val_loss: 8.5320 - val_acc: 0.1035
#
# Epoch 00133: val_acc did not improve from 0.11458
# Epoch 134/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.3265 - acc: 0.6462 - val_loss: 8.5767 - val_acc: 0.1014
#
# Epoch 00134: val_acc did not improve from 0.11458
# Epoch 135/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.3110 - acc: 0.6453 - val_loss: 8.5636 - val_acc: 0.1014
#
# Epoch 00135: val_acc did not improve from 0.11458
# Epoch 136/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.2867 - acc: 0.6524 - val_loss: 8.5965 - val_acc: 0.1042
#
# Epoch 00136: val_acc did not improve from 0.11458
# Epoch 137/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2893 - acc: 0.6479 - val_loss: 8.5738 - val_acc: 0.1090
#
# Epoch 00137: val_acc did not improve from 0.11458
# Epoch 138/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2733 - acc: 0.6616 - val_loss: 8.6030 - val_acc: 0.1021
#
# Epoch 00138: val_acc did not improve from 0.11458
# Epoch 139/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2487 - acc: 0.6660 - val_loss: 8.6160 - val_acc: 0.0986
#
# Epoch 00139: val_acc did not improve from 0.11458
# Epoch 140/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2333 - acc: 0.6682 - val_loss: 8.6440 - val_acc: 0.0993
#
# Epoch 00140: val_acc did not improve from 0.11458
# Epoch 141/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2142 - acc: 0.6701 - val_loss: 8.6937 - val_acc: 0.0958
#
# Epoch 00141: val_acc did not improve from 0.11458
# Epoch 142/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.3128 - acc: 0.6509 - val_loss: 8.6729 - val_acc: 0.0937
#
# Epoch 00142: val_acc did not improve from 0.11458
# Epoch 143/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2823 - acc: 0.6557 - val_loss: 8.6656 - val_acc: 0.0965
#
# Epoch 00143: val_acc did not improve from 0.11458
# Epoch 144/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.2605 - acc: 0.6606 - val_loss: 8.6570 - val_acc: 0.1035
#
# Epoch 00144: val_acc did not improve from 0.11458
# Epoch 145/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.2391 - acc: 0.6576 - val_loss: 8.6684 - val_acc: 0.0951
#
# Epoch 00145: val_acc did not improve from 0.11458
# Epoch 146/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2082 - acc: 0.6740 - val_loss: 8.6777 - val_acc: 0.1056
#
# Epoch 00146: val_acc did not improve from 0.11458
# Epoch 147/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.2076 - acc: 0.6722 - val_loss: 8.7061 - val_acc: 0.1035
#
# Epoch 00147: val_acc did not improve from 0.11458
# Epoch 148/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.1876 - acc: 0.6811 - val_loss: 8.7023 - val_acc: 0.0979
#
# Epoch 00148: val_acc did not improve from 0.11458
# Epoch 149/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.1643 - acc: 0.6821 - val_loss: 8.6861 - val_acc: 0.1042
#
# Epoch 00149: val_acc did not improve from 0.11458
# Epoch 150/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.1379 - acc: 0.6892 - val_loss: 8.7010 - val_acc: 0.1000
#
# Epoch 00150: val_acc did not improve from 0.11458
# Epoch 151/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.1411 - acc: 0.6905 - val_loss: 8.7459 - val_acc: 0.0986
#
# Epoch 00151: val_acc did not improve from 0.11458
# Epoch 152/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.1265 - acc: 0.6927 - val_loss: 8.7038 - val_acc: 0.1042
#
# Epoch 00152: val_acc did not improve from 0.11458
# Epoch 153/200
# 5757/5757 [==============================] - 175s 30ms/step - loss: 1.1174 - acc: 0.6958 - val_loss: 8.7445 - val_acc: 0.1028
#
# Epoch 00153: val_acc did not improve from 0.11458
# Epoch 154/200
# 5757/5757 [==============================] - 174s 30ms/step - loss: 1.1042 - acc: 0.6969 - val_loss: 8.7660 - val_acc: 0.0944
#
# Epoch 00154: val_acc did not improve from 0.11458
# Epoch 155/200
# 5757/5757 [==============================] - 176s 31ms/step - loss: 1.0878 - acc: 0.7026 - val_loss: 8.7604 - val_acc: 0.0944
#
# Epoch 00155: val_acc did not improve from 0.11458
# Epoch 156/200
# 5757/5757 [==============================] - 183s 32ms/step - loss: 1.0772 - acc: 0.7078 - val_loss: 8.7631 - val_acc: 0.1007
#
# Epoch 00156: val_acc did not improve from 0.11458
# Epoch 157/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 1.0747 - acc: 0.7153 - val_loss: 8.7677 - val_acc: 0.0965
#
# Epoch 00157: val_acc did not improve from 0.11458
# Epoch 158/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 1.0669 - acc: 0.7057 - val_loss: 8.7595 - val_acc: 0.0986
#
# Epoch 00158: val_acc did not improve from 0.11458
# Epoch 159/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0497 - acc: 0.7148 - val_loss: 8.8031 - val_acc: 0.1007
#
# Epoch 00159: val_acc did not improve from 0.11458
# Epoch 160/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0426 - acc: 0.7162 - val_loss: 8.8057 - val_acc: 0.0958
#
# Epoch 00160: val_acc did not improve from 0.11458
# Epoch 161/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0402 - acc: 0.7141 - val_loss: 8.7810 - val_acc: 0.0986
#
# Epoch 00161: val_acc did not improve from 0.11458
# Epoch 162/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0153 - acc: 0.7278 - val_loss: 8.8175 - val_acc: 0.0979
#
# Epoch 00162: val_acc did not improve from 0.11458
# Epoch 163/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0170 - acc: 0.7176 - val_loss: 8.8176 - val_acc: 0.1014
#
# Epoch 00163: val_acc did not improve from 0.11458
# Epoch 164/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 1.0050 - acc: 0.7236 - val_loss: 8.8474 - val_acc: 0.0903
#
# Epoch 00164: val_acc did not improve from 0.11458
# Epoch 165/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9882 - acc: 0.7337 - val_loss: 8.8576 - val_acc: 0.1007
#
# Epoch 00165: val_acc did not improve from 0.11458
# Epoch 166/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9843 - acc: 0.7313 - val_loss: 8.8624 - val_acc: 0.0993
#
# Epoch 00166: val_acc did not improve from 0.11458
# Epoch 167/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9544 - acc: 0.7386 - val_loss: 8.8534 - val_acc: 0.0938
#
# Epoch 00167: val_acc did not improve from 0.11458
# Epoch 168/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9472 - acc: 0.7384 - val_loss: 8.8829 - val_acc: 0.0965
#
# Epoch 00168: val_acc did not improve from 0.11458
# Epoch 169/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9491 - acc: 0.7414 - val_loss: 8.9182 - val_acc: 0.1014
#
# Epoch 00169: val_acc did not improve from 0.11458
# Epoch 170/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.9300 - acc: 0.7464 - val_loss: 8.8987 - val_acc: 0.1007
#
# Epoch 00170: val_acc did not improve from 0.11458
# Epoch 171/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.9304 - acc: 0.7427 - val_loss: 8.9242 - val_acc: 0.0896
#
# Epoch 00171: val_acc did not improve from 0.11458
# Epoch 172/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.9328 - acc: 0.7459 - val_loss: 8.9148 - val_acc: 0.0986
#
# Epoch 00172: val_acc did not improve from 0.11458
# Epoch 173/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8946 - acc: 0.7530 - val_loss: 8.9308 - val_acc: 0.0965
#
# Epoch 00173: val_acc did not improve from 0.11458
# Epoch 174/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.9059 - acc: 0.7509 - val_loss: 8.9484 - val_acc: 0.0986
#
# Epoch 00174: val_acc did not improve from 0.11458
# Epoch 175/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8845 - acc: 0.7622 - val_loss: 8.9422 - val_acc: 0.0979
#
# Epoch 00175: val_acc did not improve from 0.11458
# Epoch 176/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.9010 - acc: 0.7546 - val_loss: 8.9953 - val_acc: 0.0931
#
# Epoch 00176: val_acc did not improve from 0.11458
# Epoch 177/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8739 - acc: 0.7657 - val_loss: 8.9939 - val_acc: 0.0951
#
# Epoch 00177: val_acc did not improve from 0.11458
# Epoch 178/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8541 - acc: 0.7634 - val_loss: 9.0190 - val_acc: 0.0917
#
# Epoch 00178: val_acc did not improve from 0.11458
# Epoch 179/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8529 - acc: 0.7639 - val_loss: 9.0025 - val_acc: 0.1021
#
# Epoch 00179: val_acc did not improve from 0.11458
# Epoch 180/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8521 - acc: 0.7655 - val_loss: 9.0419 - val_acc: 0.1007
#
# Epoch 00180: val_acc did not improve from 0.11458
# Epoch 181/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.8605 - acc: 0.7610 - val_loss: 9.0560 - val_acc: 0.1097
#
# Epoch 00181: val_acc did not improve from 0.11458
# Epoch 182/200
# 5757/5757 [==============================] - 183s 32ms/step - loss: 0.8294 - acc: 0.7655 - val_loss: 9.0816 - val_acc: 0.0979
#
# Epoch 00182: val_acc did not improve from 0.11458
# Epoch 183/200
# 5757/5757 [==============================] - 188s 33ms/step - loss: 0.8230 - acc: 0.7721 - val_loss: 9.0601 - val_acc: 0.0944
#
# Epoch 00183: val_acc did not improve from 0.11458
# Epoch 184/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.8327 - acc: 0.7686 - val_loss: 9.0762 - val_acc: 0.0924
#
# Epoch 00184: val_acc did not improve from 0.11458
# Epoch 185/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.8106 - acc: 0.7728 - val_loss: 9.0749 - val_acc: 0.0972
#
# Epoch 00185: val_acc did not improve from 0.11458
# Epoch 186/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.8037 - acc: 0.7751 - val_loss: 9.0963 - val_acc: 0.0931
#
# Epoch 00186: val_acc did not improve from 0.11458
# Epoch 187/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.8438 - acc: 0.7681 - val_loss: 9.0671 - val_acc: 0.0958
#
# Epoch 00187: val_acc did not improve from 0.11458
# Epoch 188/200
# 5757/5757 [==============================] - 186s 32ms/step - loss: 0.8173 - acc: 0.7683 - val_loss: 9.0752 - val_acc: 0.0958
#
# Epoch 00188: val_acc did not improve from 0.11458
# Epoch 189/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7895 - acc: 0.7801 - val_loss: 9.0691 - val_acc: 0.0958
#
# Epoch 00189: val_acc did not improve from 0.11458
# Epoch 190/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7852 - acc: 0.7834 - val_loss: 9.0778 - val_acc: 0.0972
#
# Epoch 00190: val_acc did not improve from 0.11458
# Epoch 191/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7824 - acc: 0.7780 - val_loss: 9.1191 - val_acc: 0.0979
#
# Epoch 00191: val_acc did not improve from 0.11458
# Epoch 192/200
# 5757/5757 [==============================] - 184s 32ms/step - loss: 0.7616 - acc: 0.7883 - val_loss: 9.1244 - val_acc: 0.0972
#
# Epoch 00192: val_acc did not improve from 0.11458
# Epoch 193/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7543 - acc: 0.7841 - val_loss: 9.1306 - val_acc: 0.1014
#
# Epoch 00193: val_acc did not improve from 0.11458
# Epoch 194/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7498 - acc: 0.7966 - val_loss: 9.1160 - val_acc: 0.1076
#
# Epoch 00194: val_acc did not improve from 0.11458
# Epoch 195/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7349 - acc: 0.7992 - val_loss: 9.1476 - val_acc: 0.0958
#
# Epoch 00195: val_acc did not improve from 0.11458
# Epoch 196/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7474 - acc: 0.7876 - val_loss: 9.1549 - val_acc: 0.1000
#
# Epoch 00196: val_acc did not improve from 0.11458
# Epoch 197/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7276 - acc: 0.7928 - val_loss: 9.1703 - val_acc: 0.0965
#
# Epoch 00197: val_acc did not improve from 0.11458
# Epoch 198/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7230 - acc: 0.7975 - val_loss: 9.2317 - val_acc: 0.0951
#
# Epoch 00198: val_acc did not improve from 0.11458
# Epoch 199/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.7186 - acc: 0.7987 - val_loss: 9.2121 - val_acc: 0.0993
#
# Epoch 00199: val_acc did not improve from 0.11458
# Epoch 200/200
# 5757/5757 [==============================] - 185s 32ms/step - loss: 0.6993 - acc: 0.8081 - val_loss: 9.2550 - val_acc: 0.0986
# W0619 12:22:15.068167 140585019008896 __init__.py:44] file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/__init__.py", line 36, in autodetect
#     from google.appengine.api import memcache
# ModuleNotFoundError: No module named 'google.appengine'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 33, in <module>
#     from oauth2client.contrib.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.contrib.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 37, in <module>
#     from oauth2client.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/__init__.py", line 41, in autodetect
#     from . import file_cache
#   File "/usr/local/lib/python3.6/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 41, in <module>
#     'file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth')
# ImportError: file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# Epoch 00200: val_acc did not improve from 0.11458
# Training completed!

# %% [markdown]
# It took me many hours to train over 200 epochs on Google Colab. However, the validation acuracy only improved from 6.25% to 11.46%, while the training accuracy is at 80.81%. This means that the model is not generalizing very well. While this is unfortunate, given that my dataset is so small, this result is somewhat expected. Nonetheless, we might still get interesting outputs from the model. We shall see in the next section.

# %% [markdown]
# ## Testing the Models

# %%
from keras.models import load_model
model = load_model('model.h5')

# %% [markdown]
# The following helper function is taken from Keras's **lstm_text_generation** [example script](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py) found in its github. For text generation model, we may not always be interested in THE word that has the highest probability (i.e. safest guesses); instead, we want the model to be slightly more "creative" in its guesses of the next word. To do so, the helper function introduce a scaling factor called "temperature" which defines how conservative or creative we want the output to be. A lower "temperature" (e.g. 0.1) will lead to safer guesses, while a higher "temperature will yield "riskier" guesses.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Once again, the following generate_text function is based on Shivam Bansal's [article](https://medium.com/@shivambansal36/language-modelling-text-generation-using-lstms-deep-learning-for-nlp-ed36b224b275) with minor modification that incorporates the previously mentioned helper function.

# %%
def generate_text(seed_text, next_words, max_sequence_len, model, temp_low, temp_high):
    for j in range(next_words):
        tokenized_seed_text = tokenizer.texts_to_sequences([seed_text])[0]
        tokenized_seed_text = pad_sequences([tokenized_seed_text], 
                                            maxlen=max_sequence_len-1, 
                                            padding='pre')
        
        #for each prediction, a new "temperature" is random chosen to bring more randomness in the results
        temperature = random.uniform(temp_low,temp_high)
        
        predicted_proba = model.predict(tokenized_seed_text, verbose=0)[0]
        predicted_word = sample(predicted_proba,temperature = temperature)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_word:
                output_word = word
                break
        seed_text += " " + output_word

    return seed_text

# %% [markdown]
# To generate new Bro Codes, I will start the sequence with "a bro" (or "when a bro, "if a bro", etc) and randomly assign a sequence length and temperature. Below is one of the many trials that I ran:

# %%
import random
for n in range(10):
    word_count = random.randint(7,15)
    print(generate_text('a bro',word_count, max_seq_length, model, 2, 4))
# Out:
# a bro does not go with front of other bros .
# a bro or crosses a birthday of their women and do bro .
# a bro never facetimes . a chick hits sometimes even better bro’s pretend not the being anything
# a bro must never tamper with another chick's ex , unless the bro must ex it
# a bro doesn’t offers another bro drink and drive with if a naked to the the
# a bro shall not expected to notice and if she can
# a bro is not allowed to notice another bro’s new haircut . unless are drunk
# a bro is not required to fail of at all drunk , all
# a bro never cries , with bro and only be results the agreed the existence
# a bro doesn’t allow another bro to another anything if they or revenge of

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As expected, the model generates the exact sequences from the Bro Codes many times due to overfitting; yet, it still managed to come up with some novel ones:
# - 'A bro is unacceptable in sandals.'
# - 'A bro is honor bound to drink'
# - 'A bro always grow a moustache of armpits'
# - 'A bro will not sleep in front of bros. no'
# - 'A bro never tickles another bro's muscles'
# - 'A bro will order any type of alcoholic drink she wants'
# - 'A bro is honour bound to accept all style chick'
# - 'A bro does not choose his own wrestling challenges when a chick orders'
# - 'A bro never gives another bro’s toothbrush they wouldn’t try them self .'
# - 'A bro never willingly relinquishes possession of a bachelor party'
# - 'A bro never lets another bro drink with any married bros'
# - 'A bro will only be supportive of all decisions of his side chicks .'
# - 'A bro is honor bound to his wife .'
# - 'A bro is always completely respectful to music in a bar'
# - 'When a bro is in doubt , he shall consider the actions of chuck norris'
#
# These ones make no sense, but are still grammatically correct (to a certain extent):
# - 'If a bro asks out a guitar at a party , he will leave a quarter'
# - 'If a bro asks , a chick may not be tolerated in another bro to toss a banana'
# - 'When a bro dies while lifting weights  , he is required to sit him twice before she must honor the weird wait three days'
# - 'A bro never facetimes , skypes or uses any other guy and chair for cue .'
# - 'A bro never borrows or lends clothes of another bro to eating a banana '

# %% [markdown]
# ## Reference

# %% [markdown]
# [1] S. Bansal, 'Language Modelling and Text Generation using LSTMs — Deep Learning for NLP', 2018. [Online]. Available: https://medium.com/@shivambansal36/language-modelling-text-generation-using-lstms-deep-learning-for-nlp-ed36b224b275. [Accessed: 21- June- 2019]
#
# [2] Keras Team, 'lstm_text_generation.py', 2019. [Online]. Available: https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py . [Accessed: 21- June- 2019]
